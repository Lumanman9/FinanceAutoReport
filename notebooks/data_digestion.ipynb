# %%
pwd
# Out:
# '/Users/manqin/FinanceAutoReport/notebooks'

# %%
import os
import sys

repo_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if repo_root not in sys.path:
    sys.path.insert(0, repo_root)

print("Repo root added to sys.path:", repo_root)
# Out:
# Repo root added to sys.path: /Users/manqin/FinanceAutoReport

# %%
from data_digestion.data_digestion import *

# %%
input_folder = "/Users/manqin/FinanceAutoReport/data/新海"
output_folder = "/Users/manqin/FinanceAutoReport/output/新海"
os.makedirs(output_folder, exist_ok=True)

print("Input:", input_folder)
print("Output:", output_folder)
# Out:
# Input: /Users/manqin/FinanceAutoReport/data/新海
# Output: /Users/manqin/FinanceAutoReport/output/新海

# %%
env_path = os.path.join(repo_root, ".env")
if os.path.exists(env_path):
    with open(env_path, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line or line.startswith("#") or "=" not in line:
                continue
            key, value = line.split("=", 1)
            if key and key not in os.environ:
                os.environ[key] = value.strip().strip("\"").strip("'")
print("Loaded .env from:", env_path)
# Out:
# Loaded .env from: /Users/manqin/FinanceAutoReport/.env

# %%
api_key = os.getenv("OPENAI_API_KEY")
if not api_key:
    raise RuntimeError("OPENAI_API_KEY is not set. Set it before running this cell.")

print("OPENAI_API_KEY is set.")
# Out:
# OPENAI_API_KEY is set.

# %%
digester = OpenaiVLMDataDigester(model_name="gpt-5.4")

main(
    input_folder,
    output_folder,
    digester,
    store_mode="json",
)

print("Done. JSONL saved to:", os.path.join(output_folder, "vlm_chunks.jsonl"))
# Out:
# Processing 新海开户许可证20000520.pdf
# Skipping already processed file: 新海开户许可证20000520.pdf
# Finished Processing 新海开户许可证20000520.pdf
# Processing 新海中国银行2025年.xls
# Skipping already processed file: 新海中国银行2025年.xls
# Finished Processing 新海中国银行2025年.xls
# Processing 新海邮储2025流水.xls
# Skipping already processed file: 新海邮储2025流水.xls
# Finished Processing 新海邮储2025流水.xls
# Processing 新海营业执照（正本）.jpg
# Skipping already processed file: 新海营业执照（正本）.jpg
# Finished Processing 新海营业执照（正本）.jpg
# Processing 新海工行新竹路支行2025流水.xlsx
# Skipping already processed file: 新海工行新竹路支行2025流水.xlsx
# Finished Processing 新海工行新竹路支行2025流水.xlsx
# Processing 新海平安银行2025年流水.xlsx
# Skipping already processed file: 新海平安银行2025年流水.xlsx
# Finished Processing 新海平安银行2025年流水.xlsx
# Processing 新海营业执照（副本）.jpg
# Skipping already processed file: 新海营业执照（副本）.jpg
# Finished Processing 新海营业执照（副本）.jpg
# Processing 新海高新技术企业证书（2023年）.pdf
# Skipping already processed file: 新海高新技术企业证书（2023年）.pdf
# Finished Processing 新海高新技术企业证书（2023年）.pdf
# ...
